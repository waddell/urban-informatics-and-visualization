# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import pandana as pdna
from pandana import utils
import geopandas.io.osm as osm
# %matplotlib inline

# %% [markdown]
# ## Read in the network and initialize

# %%
store = pd.HDFStore('data/osm_bayarea.h5', "r")
net=pdna.Network(store.nodes["x"], 
                 store.nodes["y"], 
                 store.edges["from"], 
                 store.edges["to"], 
                 store.edges[["weight"]])

# make sure you have enough categories for your score
net.init_pois(num_categories=10, max_dist=2400, max_pois=10)

bbox = [-122.8662,37.1373,-121.4798,38.2158] # san francisco

# %% [markdown]
# ## Make a decay function

# %%
from scipy.special import expit
def dist_to_contrib(dist):
    dist = dist.astype('float') / 2400 # now varies from 0 to 1
    dist = (dist * -10) + 5
    return expit(dist)

# %% [markdown]
# ## Create an anything score

# %%
s = utils.anything_score(
    net,
    {
        "shop=supermarket": [3.0],
        "amenity=restaurant": [.75, .45, .25, .25, .225, .225, .225, .225, .2, .2],
        "shop=convenience": [.5, .45, .4, .35, .3],
        "amenity=cafe": [1.25, .75],
        "amenity=bank": [1.0],
        "leisure=park": [1.0],
        "amenity=school": [1.0],
        "amenity=library": [1.0],
        "amenity=bar": [1.0]
    },
    2400,
    dist_to_contrib, # decay function to apply to distance
    bbox
)
print s.describe()
# Out:
# Computing for query: leisure=park
# Fetching nodes from OSM
# Found 789 nodes
# Done
# Computing nearest
# Done
# Adding contribution 1.000000 for number 1 nearest
# Computing for query: amenity=restaurant
# Fetching nodes from OSM
# Found 2771 nodes
# Done
# Computing nearest
# Done
# Adding contribution 0.750000 for number 1 nearest
# Adding contribution 0.450000 for number 2 nearest
# Adding contribution 0.250000 for number 3 nearest
# Adding contribution 0.250000 for number 4 nearest
# Adding contribution 0.225000 for number 5 nearest
# Adding contribution 0.225000 for number 6 nearest
# Adding contribution 0.225000 for number 7 nearest
# Adding contribution 0.225000 for number 8 nearest
# Adding contribution 0.200000 for number 9 nearest
# Adding contribution 0.200000 for number 10 nearest
# Computing for query: amenity=school
# Fetching nodes from OSM
# Found 1377 nodes
# Done
# Computing nearest
# Done
# Adding contribution 1.000000 for number 1 nearest
# Computing for query: amenity=library
# Fetching nodes from OSM
# Found 153 nodes
# Done
# Computing nearest
# Done
# Adding contribution 1.000000 for number 1 nearest
# Computing for query: shop=supermarket
# Fetching nodes from OSM
# Found 327 nodes
# Done
# Computing nearest
# Done
# Adding contribution 3.000000 for number 1 nearest
# Computing for query: amenity=bank
# Fetching nodes from OSM
# Found 436 nodes
# Done
# Computing nearest
# Done
# Adding contribution 1.000000 for number 1 nearest
# Computing for query: shop=convenience
# Fetching nodes from OSM
# Found 336 nodes
# Done
# Computing nearest
# Done
# Adding contribution 0.500000 for number 1 nearest
# Adding contribution 0.450000 for number 2 nearest
# Adding contribution 0.400000 for number 3 nearest
# Adding contribution 0.350000 for number 4 nearest
# Adding contribution 0.300000 for number 5 nearest
# Computing for query: amenity=bar
# Fetching nodes from OSM
# Found 244 nodes
# Done
# Computing nearest
# Done
# Adding contribution 1.000000 for number 1 nearest
# Computing for query: amenity=cafe
# Fetching nodes from OSM
# Found 893 nodes
# Done
# Computing nearest
# Done
# Adding contribution 1.250000 for number 1 nearest
# Adding contribution 0.750000 for number 2 nearest
# count    226060.000000
# mean         16.688139
# std          20.881168
# min           0.684265
# 25%           0.684265
# 50%           8.206257
# 75%          23.883889
# max         100.000000
# dtype: float64

# %% [markdown]
# ## See it

# %%
out_bbox = utils.bbox_convert([-122.539365,37.693047,-122.347698,37.816069], 
                              from_epsg=4326, to_epsg=3740)
net.plot(s, bbox=out_bbox, scheme="diverging", color="BrBG")

# %%
gdf = utils.gdf_from_network(net, s, 3740)
gdf = gdf.to_crs(epsg=3857)

# %%
df = utils.gdf_points_to_xy(gdf)

# %%
df["x"] = df["x"].astype("int")
df["y"] = df["y"].astype("int")
df.to_csv("analysis.csv", index=False, float_format="%.2f")
#open("analysis.geojson", "w").write(gdf.to_json())
