# %% [markdown]
# # Spatial databases with PostgreSQL and PostGIS
#
# ## Installation
#
# This tutorial requires pandas, sqlalchemy, and [psycopg2](http://initd.org/psycopg/) (PostgreSQL adapter for Python).
#
# ### Windows
#
# If you are using Anaconda, pandas and sqlalchemy should already be installed. Install psycopg2 from a third-party repository using conda:
#
#     conda install -c https://conda.binstar.org/topper psycopg2-win32-py27 (for 32-bit)
#     conda install -c https://conda.binstar.org/topper psycopg2-windows    (for 64-bit)
#
# Alternatively, you can download and install [win-psycopg2](http://www.stickpeople.com/projects/python/win-psycopg/).
#
# ### Mac OS X
#
# If you are using Anaconda, pandas and sqlalchemy should already be installed. Installing psycopg2 on Mac OS X with support for Anaconda could be tricky. There are a few options to try:
#
# 1. Use Synthicity's repository:
#
#         conda install -c https://conda.binstar.org/synthicity psycopg2
#
#    However, this has only been tested with an existing Homebrew install of PostgreSQL and might not work without it.
#
# 2. Use [fink or MacPorts](http://initd.org/psycopg/docs/install.html).
#
# 3. Run `pip install psycopg2`. This might require setting some environment variables and might not be compatible with Anaconda.
#
# ### Debian and Ubuntu
#
# Install these system packages:
#
#  - python-pandas
#  - python-sqlalchemy
#  - python-psycopg2
#
# ## About PostgreSQL and PostGIS
#
# PostGIS extends PostgreSQL, a relational database, to work with spatial data, like points, lines, and polygons. Both PostGIS and PostgreSQL are free/libre open source software. PostgreSQL was originally developed at UC Berkeley.
#
# Relational databases store information in tables containing rows and columns. Like Pandas, each column is of a specific data type. Relational databases are commonly used for data entry and web applications.
#
# Advantages of (relational) databases:
#
#  - Flexibility. The [Structured Query Language](https://en.wikipedia.org/wiki/SQL) (SQL) enables complex queries for extracting or inserting data.
#  - Performance. Commonly-used columns can be indexed or cached in memory.
#  - Normalization. Each record is stored in a single table, but can be referenced multiple times, avoiding duplication and simplifying updates.
#  - Consistency. Constraints and data types prevent missing references and invalid values.
#  - Concurrent use. Transactions allow multiple users (local or remote) to read and write data simultaneously.
#  - Reliability and redundancy. Data can be served by multiple servers.
#
# It is possible to avoid SQL by using an Object Relational Mapper (ORM) that translates between SQL and an object-oriented language like Python, but today we'll be working directly with SQL, which is flexible and powerful.
#
# ### A hypothetical relational database
#
# A tax assessor maintaining property records might create tables for cities, parcels, and buildings. In SQL,
#
#     CREATE TABLE cities (
#       id serial PRIMARY KEY,
#       name varchar(80) NOT NULL
#     )
#
#     CREATE TABLE parcels (
#       id serial PRIMARY KEY,
#       value real,
#       assessed date,
#       city int references cities(id) NOT NULL,
#     )
#
#     CREATE TABLE buildings (
#       id serial PRIMARY KEY,
#       built date,
#       units int,
#       parcel int references parcels(id) NOT NULL,
#     )
#
# Advantages of this database:
#
#   - Consistency. The database will enforce primary key and not null constraints and foreign key references.
#       - primary key constraint: No records with the same ID can exist.
#       - serial data type: The next available ID will automatically be used when a record is added.
#       - foreign key reference, not null constraint: Each building references a parcel which in turn references a city. Before a building record can be added, its parcel record must be added. And the parcel record cannot be later deleted without cascading the deletion to any buildings that reference it.
#   - Fast aggregate operations.
#     - Can quickly calculate the up-to-date average assessed value or number of units in each city. Indexing on the primary key constraint makes this fast.
#   - Concurrent use. Multiple clerks can view and modify the data simultaneously.
#
# Data is often not so cleanly hierarchically. And in practice, it is imported from multiple sources that do not cleanly reference each other.
#
# Luckily, GIS data contains spatial information. A relational database that is spatially-aware, like PostgreSQL with PostGIS, can work with spatial relationships, for example, whether a parcel is geometrically contained within a city or whether a parcel is near a transit station.
#
# ## Our database schema
#
# For this tutorial, we will be working with several tables, each containing several columns (fields).
#
# | Table            | Column     | Description                                          |
# |------------------|------------|------------------------------------------------------|
# | actransit_routes |            | AC Transit bus routes (August 2014)                  |
# |                  | route      | Route name                                           |
# |                  | geom       | Line geometry                                        |
# | actransit_stops  |            | AC Transit bus stops (August 2014)                   |
# |                  | id         | 511 stop ID                                          |
# |                  | stop       | Stop name                                            |
# |                  | routes     | Routes serving stop separated by spaces              |
# |                  | geom       | Point geometry                                       |
# | alameda_blocks   |            | Alameda County (2010) Census blocks                  |
# |                  | fips       | 15-digit FIPS code that uniquely identifies block    |
# |                  | pop_total  | Total population                                     |
# |                  | pop_white  | Population - White alone                             |
# |                  | pop_black  | Population - Black or African American alone         |
# |                  | pop_native | Population - American Indian and Alaska Native alone |
# |                  | pop_asian  | Population - Asian alone                             |
# |                  | pop_other  | Population - Other or multiple races                 |
# |                  | geom       | Polygon geometry                                     |
# | alameda_cities   |            | Alameda County city limits (October 2014)            |
# |                  | name       | City name, otherwise 'Alameda County'                |
# |                  | geom       | Polygon geometry                                     |
# | bart_routes      |            | BART routes (October 2013)                           |
# |                  | route      | Route name                                           |
# |                  | lines      | Route color                                          |
# |                  | geom       | Line geometry                                        |
# | bart_stations    |            | BART stations (October 2013)                         |
# |                  | station    | Station name                                         |
# |                  | geom       | Point geometry                                       |
# | berkeley_land    |            | City of Berkeley land area (October 2011)            |
# |                  | geom       | Polygon geometry                                     |
#
#  We can view the database tables in QGIS.

# %%
from IPython.display import Image
Image('qgis-postgis-tables.png')

# %%
# Does this look familiar?
Image('qgis-postgis-canvas.png')

# %% [markdown]
# ## Interacting with the database

# %% [markdown]
# SQL has four "verbs" for interacting with data in tables.
#
#  - [`SELECT`](http://www.postgresql.org/docs/current/interactive/sql-select.html), returns rows in response to a query
#  - [`INSERT`](http://www.postgresql.org/docs/current/interactive/sql-insert.html), adds new rows to a table
#  - [`UPDATE`](http://www.postgresql.org/docs/current/interactive/sql-update.html), alters existing rows in a table
#  - [`DELETE`](http://www.postgresql.org/docs/current/interactive/sql-delete.html), removes rows from a table
#
# We will be mostly working with `SELECT`.

# %%
from pandas.io import sql
from sqlalchemy import create_engine

# Describe database connection.
# Fill in your assigned username and password.
username = 'cp255_00'
password = '214wurster'
url = 'postgresql://{0}:{1}@tehran.ual.berkeley.edu/cp255'.format(username, password)
engine = create_engine(url)
execute = engine.execute
query = lambda q: sql.read_sql_query(q, engine)

# %% [markdown]
# ### Simple queries

# %%
# Query PostGIS version using function.
query("SELECT postgis_full_version();")
# Out:
#                                 postgis_full_version
# 0  POSTGIS="2.1.4 r12966" GEOS="3.4.2-CAPI-1.8.2 ...

# %%
# Query 1 and 1R bus routes
query("""
    SELECT *                          -- column(s) to return, * means all
    FROM actransit_routes             -- table(s) to query
    WHERE route = '1' OR route = '1R' -- filter condition(s)
    ORDER BY route ASC                -- sort criteria(s)
    LIMIT 10;                         -- maximum number of records to return
""")
# Out:
#    gid route                                               geom
# 0    1     1  0105000020D00A0000F900000001020000000C00000036...
# 1   23    1R  0105000020D00A00007000000001020000000A0000000D...

# %%
# Query bus stops on Bancroft served by the 1 bus.
# Note: SQL globbing uses '%'. We escape with '%%' because '%' is used in
#       Python for string formatting, e.g., "My name is %s." % name
query("""
    SELECT id, stop, routes
    FROM actransit_stops
    WHERE stop LIKE '%%Bancroft%%'
          AND routes LIKE '1 %%';
""")
# Out:
#       id                       stop                     routes
# 0  55593       Bancroft Way:Dana St  1 F 49 52 51B 604 605 851
# 1  54655  Bancroft Way:Ellsworth St  1 F 49 52 51B 604 605 851
# 2  51078  Telegraph Av:Bancroft Way                       1 1R

# %%
# Query five census blocks with races expressed as percentages.
# Note: need to use floats instead of integer math.
query("""
    SELECT fips, pop_total,
           100. * pop_white  / pop_total AS pct_white,
           100. * pop_black  / pop_total AS pct_black,
           100. * pop_native / pop_total AS pct_native,
           100. * pop_asian  / pop_total AS pct_asian,
           100. * pop_other  / pop_total AS pct_other
    FROM alameda_blocks
    WHERE pop_total > 0
    ORDER BY fips ASC
    LIMIT 5;
""")
# Out:
#               fips  pop_total   pct_white  pct_black  pct_native  pct_asian  \
# 0  060014001001007        117   85.470085          0           0   7.692308
# 1  060014001001008         20   80.000000          0           0  10.000000
# 2  060014001001011         13   92.307692          0           0   7.692308
# 3  060014001001013          1  100.000000          0           0   0.000000
# 4  060014001001014         20   90.000000          0           0  10.000000
#
#    pct_other
# 0   6.837607
# 1  10.000000
# 2   0.000000
# 3   0.000000
# 4   0.000000

# %%
# Query total Alameda County population with aggregate function sum.
query("""
    SELECT sum(pop_total) / 1e6 AS county_pop
    FROM alameda_blocks;
""")
# Out:
#    county_pop
# 0    1.510271

# %%
# Query cities in Alameda County.
query("SELECT name FROM alameda_cities")
# Out:
#               name
# 0       Emeryville
# 1         Piedmont
# 2          Alameda
# 3         Berkeley
# 4           Albany
# 5      San Leandro
# 6           Newark
# 7           Dublin
# 8       Pleasanton
# 9          Oakland
# 10         Fremont
# 11       Livermore
# 12         Hayward
# 13      Union City
# 14  Alameda County

# %%
# Query BART routes.
query("SELECT route, line FROM bart_routes;")
# Out:
#                                     route    line
# 0                     Fremont to Richmond  Orange
# 1          Dublin/Pleasanton to Daly City    Blue
# 2                 Millbrae to SFO Shuttle    None
# 3                    Fremont to Daly City   Green
# 4       Richmond to Daly City to Millbrae     Red
# 5  Pittsburg/Bay Point to SFO to Millbrae  Yellow

# %%
# Query five BART stations sorted reverse alphabetically.
query("""
    SELECT station
    FROM bart_stations
    ORDER BY station DESC
    LIMIT 5;
""")
# Out:
#                   station
# 0            WEST OAKLAND
# 1  WEST DUBLIN/PLEASANTON
# 2            WALNUT CREEK
# 3              UNION CITY
# 4     SOUTH SAN FRANCISCO

# %%
# Query Berkeley land polygon as a well-known binary (WKB).
# This is not very useful as a string.
query("SELECT geom FROM berkeley_land;")
# Out:
#                                                 geom
# 0  0106000020D00A0000010000000103000000010000006D...

# %% [markdown]
# ### Simple query exercises

# %% [markdown]
# For these exercises, you may need to use a [PostgreSQL aggregate function](http://www.postgresql.org/docs/current/static/functions-aggregate.html):
#
#  - `avg(expression)`
#  - `count(*)`
#  - `sum(expression)`

# %% [markdown]
# How many AC transit bus routes exist?

# %%
# Out:
#    count
# 0    153

# %% [markdown]
# How many AC Transit bus stops are on Telegraph?

# %%
# Out:
#    count
# 0     69

# %% [markdown]
# What is the average population of a Census block in Alameda County, excluding blocks without residents?

# %%
# Out:
#       pop_avg
# 0  107.248331

# %% [markdown]
# What percent of the population in Alameda County is Black or African American alone?

# %%
# Out:
#    pct_black
# 0  12.610386

# %% [markdown]
# Which Census block in Alameda County, with more than 200 residents, has the highest percent Asian alone? Hint: use `ORDER BY` and `LIMIT`.

# %%
# Out:
#               fips  pct_asian  pop_asian
# 0  060014033002009        100        261

# %%
# Census block appears to be in Oakland Chinatown.
# Copyright 2014 Google (map data), DigitalGlobe (imagery).
Image('qgis-fips-060014033002009.jpg')

# %% [markdown]
# Which BART route is labeled orange, ignorning case? Hint: use the [`lower(string)`](http://www.postgresql.org/docs/current/static/functions-string.html) function.

# %%
# Out:
#                  route
# 0  Fremont to Richmond

# %% [markdown]
# ### Geometry columns

# %% [markdown]
# So far, we worked with non-spatial data. However, each table has a geometry column named `geom`, which represents points, lines, or polygons. This allows us to work with spatial relationships.
#
# PostGIS includes a `geometry_columns` view. A view is a stored query that acts like a table. Each record (row) of this view describes a geometry column in the database.

# %%
query("SELECT * FROM geometry_columns;")
# Out:
#   f_table_catalog f_table_schema      f_table_name f_geometry_column  \
# 0           cp255         public       bart_routes              geom
# 1           cp255         public  actransit_routes              geom
# 2           cp255         public   actransit_stops              geom
# 3           cp255         public     berkeley_land              geom
# 4           cp255         public    alameda_cities              geom
# 5           cp255         public     bart_stations              geom
# 6           cp255         public    alameda_blocks              geom
#
#    coord_dimension  srid             type
# 0                2  2768  MULTILINESTRING
# 1                2  2768  MULTILINESTRING
# 2                2  2768            POINT
# 3                2  2768     MULTIPOLYGON
# 4                2  2768     MULTIPOLYGON
# 5                2  2768            POINT
# 6                2  2768     MULTIPOLYGON

# %% [markdown]
# Most of these columns should be self-expalanatory. The "MULTI" in the type means that multiple geometries can be stored as a collection in each record, e.g., a route can consist of multiple links, each represented as a line.
#
# The SRID is a unique number that identifies the projection. We reprojected the data to a consistent projection for faster spatial operations between tables. We can view more information on our projection by querying the `spatial_ref_sys` table, also included with PostGIS.

# %%
query("SELECT * FROM spatial_ref_sys WHERE srid=2768;")
# Out:
#    srid auth_name  auth_srid  \
# 0  2768      EPSG       2768
#
#                                               srtext  \
# 0  PROJCS["NAD83(HARN) / California zone 3",GEOGC...
#
#                                            proj4text
# 0  +proj=lcc +lat_1=38.43333333333333 +lat_2=37.0...

# %% [markdown]
# European Petroleum Survey Group (EPSG) is an authority that standardizes these SRID numbers. Our projection is called NAD83(HARN) / California zone 3. Zone 3 in the California State Plane coordinate system includes the Bay Area.

# %%
Image('http://www.conservation.ca.gov/cgs/information/geologic_mapping/state_plane/PublishingImages/state_plane_index2.jpg')

# %% [markdown]
# ### Simple geometry functions

# %% [markdown]
# PostgreSQL includes functions like `lower` that act on strings and aggregate functions like `count`, `sum`, and `average` that act on numbers. PostGIS extends PostgreSQL with functions that act on geometry data types.
#
# Let's look at some examples:
#
#  - [`ST_Length`](http://postgis.net/docs/ST_Length.html)
#  - [`ST_Area`](http://postgis.net/docs/ST_Area.html)
#
# Our results will be in units of meters as defined by our projection.
#
# The database stores information internally in a custom binary format, but we can easily serialize it in [well-known text](https://en.wikipedia.org/wiki/Well-known_text) (WKT) format using the [`ST_AsText`](http://postgis.net/docs/ST_AsText.html) function. We can also use [`ST_AsEWKT`](http://postgis.net/docs/ST_AsEWKT.html), which includes projection information, or [`ST_AsGeoJSON`](http://postgis.net/docs/ST_AsGeoJSON.html), which outputs [GeoJSON](https://en.wikipedia.org/wiki/GeoJSON).

# %%
for function in ["ST_AsText", "ST_AsEWKT", " ST_AsGeoJSON"]:
    print(query("""
        SELECT {}(geom) AS geom
        FROM actransit_stops
        LIMIT 1;
    """.format(function))['geom'][0])
# Out:
# POINT(1842473.97009006 642813.555974812)
# SRID=2768;POINT(1842473.97009006 642813.555974812)
# {"type":"Point","coordinates":[1842473.97009006,642813.555974812]}

# %% [markdown]
# Our projection coordinates aren't very readable. Let's try reprojecting with the `ST_Transform` function to WGS 84, which is in units of degrees latitude/longitude.

# %%
# First, need to find the SRID for WGS 84.
query("""
    SELECT *
    FROM spatial_ref_sys
    WHERE srtext LIKE 'GEOGCS["WGS 84%%'
""")
# Out:
#    srid auth_name  auth_srid  \
# 0  4326      EPSG       4326
#
#                                               srtext  \
# 0  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
#
#                               proj4text
# 0  +proj=longlat +datum=WGS84 +no_defs

# %%
query("""
    SELECT ST_AsText(ST_Transform(geom,4326)) AS geom
    FROM actransit_stops
    LIMIT 1;
""")['geom'][0]
# Out:
# u'POINT(-122.2882275 37.7732680999998)'

# %%
# Query Alameda County area in square miles.
# We assume that county is entirely covered by non-overlapping parcels.
query("""
    SELECT sum(ST_Area(geom)) / 4047 / 640 AS alameda_blocks_area
    FROM alameda_blocks;
""")
# Out:
#    alameda_blocks_area
# 0           821.188087

# %%
# Query Alameda County area in square miles.
# Aggregating blocks and cities have similar values.
query("""
    SELECT sum(ST_Area(geom)) / 4047 / 640 AS alameda_cities_area
    FROM alameda_cities;
""")
# Out:
#    alameda_cities_area
# 0           821.315341

# %%
# Query area of each city in square miles.
query("""
    SELECT name,
           ST_Area(geom) / 4047 / 640 AS area
    FROM alameda_cities
    WHERE name <> 'Alameda County';
""")
# Out:
#            name       area
# 0    Emeryville   2.259682
# 1      Piedmont   1.695325
# 2       Alameda  22.915658
# 3      Berkeley  18.067463
# 4        Albany   4.878620
# 5   San Leandro  15.467609
# 6        Newark  14.061220
# 7        Dublin  15.228352
# 8    Pleasanton  24.212653
# 9       Oakland  77.982338
# 10      Fremont  89.005789
# 11    Livermore  26.440394
# 12      Hayward  64.335640
# 13   Union City  19.395165

# %%
# Query lengths of AC Transit routes longer than 40 mi.
query("""
    SELECT route,
           ST_Length(geom) / 1609 AS actransit_lengths
    FROM actransit_routes
    WHERE ST_Length(geom) > 40 * 1609
    ORDER BY actransit_lengths DESC
""")
# Out:
#   route  actransit_lengths
# 0    SB          75.359433
# 1     S          54.742828
# 2   NX4          52.439532
# 3   801          52.280526
# 4   800          47.690623
# 5    LA          46.562234
# 6   DB1          42.451775

# %%
# Query BART track mileage in miles.
query("""
    SELECT sum(ST_Length(geom)) / 1609 AS bart_length
    FROM bart_routes;
""")
# Out:
#    bart_length
# 0   219.577735

# %% [markdown]
# ### Comparison geometry functions

# %% [markdown]
# In a non-spatial database, like one mantained by our hypothetical tax assessor, the Census blocks table would contain a column that identifies each row's city and county. The total population of a city could be determined by aggregating all of the Census blocks matching that city. In a spatial database, this relationship can be done with spatial functions that compare geometries.
#
# Let's look at some examples:
#
#  - [`ST_Intersection`](http://postgis.net/docs/ST_Intersection.html): whether interiors intersect
#  - [`ST_Within`](http://postgis.net/docs/ST_Within.html):  whether fully contained within the other
#  - [`ST_Contains`](http://postgis.net/docs/ST_Contains.html): `ST_Within` with reversed argument order
#  - [`ST_Distance`](http://postgis.net/docs/ST_Distance.html): shortest distance
#  - [`ST_DWithin`](http://postgis.net/docs/ST_DWithin.html): whether within some distance of the other

# %%
# From Introduction to PostGIS by Boundless
Image('http://workshops.boundlessgeo.com/postgis-intro/_images/st_intersects.png')

# %%
# From Introduction to PostGIS by Boundless
Image('http://workshops.boundlessgeo.com/postgis-intro/_images/st_within.png')

# %%
# Total population of Berkeley, include all blocks that intersect.
query("""
    SELECT sum(pop_total) AS berkeley_pop
    FROM alameda_blocks,
         berkeley_land
    WHERE ST_Intersects(alameda_blocks.geom, berkeley_land.geom);
""")
# Out:
#    berkeley_pop
# 0        115812

# %%
# Total population of Berkeley, exclude blocks that are not fully within.
query("""
    SELECT sum(pop_total) AS berkeley_pop
    FROM alameda_blocks,
         berkeley_land
    WHERE ST_Within(alameda_blocks.geom, berkeley_land.geom);
""")
# Out:
#    berkeley_pop
# 0        106697

# %% [markdown]
# Should we use `ST_Intersects` or `ST_Within`/`ST_Contains` to aggregate the Census blocks in Berkeley? We can inspect the difference by creating a new table containing blocks that intersect with Berkeley's land polygon but are not fully contained within it. We can then view this table in QGIS.

# %%
execute("""
    DROP TABLE IF EXISTS partial_blocks;
    CREATE TABLE partial_blocks AS
      SELECT blocks.fips,
             blocks.geom
      FROM alameda_blocks AS blocks,
           berkeley_land  AS land
      WHERE ST_Intersects(blocks.geom, land.geom)
            AND NOT ST_Within(blocks.geom, land.geom);
""")

# %%
Image('qgis-partial-blocks.png')

# %% [markdown]
# Looks like `ST_Intersects` included blocks which are not in Berkeley (upper bound) and `ST_Within`/`ST_Contains` excluded blocks which are within Berkeley (lower bound). More about this later.
#
# A naive approach would be to take an average of the two values. A better approach would be to add more logic to our query. For example, we could include all blocks that are mostly (>50%) covered by Berkeley's polygon. A good query would be efficient and begin with functions that are fast to calculate, like `ST_Intersects`, then `ST_Within`, then calculate the proportion of overlap.

# %%
# Bad, inefficient query.
#query("""
#    SELECT sum(pop_total) AS berkeley_pop
#    FROM alameda_blocks AS blocks,
#         berkeley_land  AS land
#    WHERE ST_Area(
#            ST_Intersection(blocks.geom, land.geom)
#          ) / ST_Area(blocks.geom) > 0.5;
#""")

# %%
# Good, efficient query. 100 times faster. Really.
query("""
    SELECT sum(pop_total) AS berkeley_pop
    FROM alameda_blocks AS blocks,
         berkeley_land  AS land
    WHERE ST_Intersects(blocks.geom, land.geom) AND
          (
            ST_Within(blocks.geom, land.geom) OR
            ST_Area(
              ST_Intersection(blocks.geom, land.geom)
            ) / ST_Area(blocks.geom) > 0.5
          );
""")
# Out:
#    berkeley_pop
# 0        112474

# %% [markdown]
# Checking whether geometeries intersect is relatively fast. The database uses a spatial index to quickly eliminate records outside bounding boxes. In the image below, to check which geometries intersect with the star, the database would first look at the bounding box. Thus, it can eliminate the green line before making exact computations. In practice, PostGIS breaks the bounding box into rectangles, sub-rectangles, etc. for finer indexing. `ST_Intersects` is faster than `ST_Within` because it only needs to find a point of intersection, not ensure that all interior points intersect.

# %%
# From Introduction to PostGIS by Boundless
Image('http://workshops.boundlessgeo.com/postgis-intro/_images/bbox.png')

# %%
# Count AC Transit bus stops in Berkeley.
query("""
    SELECT count(*)
    FROM actransit_stops,
         alameda_cities
    WHERE name = 'Berkeley'
          AND ST_Within(actransit_stops.geom, alameda_cities.geom);
""")
# Out:
#    count
# 0    560

# %%
# Query distance between bus stops for BART and the station itself.
query("""
    SELECT station,
           stop,
           routes,
           ST_Distance(bart_stations.geom, actransit_stops.geom) AS distance
    FROM bart_stations,
         actransit_stops
    WHERE station = 'DOWNTOWN BERKELEY'
          AND stop LIKE '%%(Berkeley BART%%'
    ORDER BY distance;
"""
)
# Out:
#              station                                           stop  \
# 0  DOWNTOWN BERKELEY  Shattuck Sq:Center St (Berkeley BART Station)
# 1  DOWNTOWN BERKELEY  Center St:Shattuck Av (Berkeley BART Station)
# 2  DOWNTOWN BERKELEY  Center St:Shattuck Sq (Berkeley BART Station)
#
#                    routes    distance
# 0  F 18 1R 49 604 605 851   72.309069
# 1                      88   84.336362
# 2                       1  107.737471

# %%
# Query shortest distance between Oakland BART stations and Berkeley.
query("""
    SELECT station,
           ST_Distance(bart.geom, berkeley.geom) / 1609 AS distance
    FROM bart_stations AS bart,
         berkeley_land AS berkeley,
         alameda_cities AS cities
    WHERE ST_Within(bart.geom, cities.geom)
          AND cities.name = 'Oakland'
    ORDER BY distance;
"""
)
# Out:
#                           station  distance
# 0                       ROCKRIDGE  0.438986
# 1                       MACARTHUR  1.245639
# 2             19TH STREET/OAKLAND  2.639487
# 3                    WEST OAKLAND  2.976926
# 4     12TH ST/OAKLAND CITY CENTER  2.993679
# 5                    LAKE MERRITT  3.372144
# 6                       FRUITVALE  5.395586
# 7  COLISEUM/OAKLAND AIRPORT (OAK)  7.090758

# %%
# From Introduction to PostGIS by Boundless
Image('http://workshops.boundlessgeo.com/postgis-intro/_images/st_dwithin.png')

# %%
# Query bus stops within 200m of Berkeley BART.
query("""
    SELECT stop,
           routes,
           ST_Distance(bart.geom, bus.geom) AS distance
    FROM bart_stations AS bart,
         actransit_stops AS bus
    WHERE station = 'DOWNTOWN BERKELEY'
          AND ST_DWithin(bus.geom, bart.geom, 200)
    ORDER BY distance;
"""
)
# Out:
#                                             stop  \
# 0                        Shattuck Av:Allston Way
# 1                        Allston Way:Shattuck Av
# 2                        Allston Way:Shattuck Av
# 3  Shattuck Sq:Center St (Berkeley BART Station)
# 4  Center St:Shattuck Av (Berkeley BART Station)
# 5  Center St:Shattuck Sq (Berkeley BART Station)
# 6                          Shattuck Sq:Center St
# 7                       Shattuck Av:Kittredge St
# 8                          Shattuck Av:Center St
# 9                       Shattuck Av:Kittredge St
#
#                            routes    distance
# 0        1 F 18 1R 49 51B 800 851   25.647182
# 1                              12   47.216695
# 2                            7 67   57.221904
# 3          F 18 1R 49 604 605 851   72.309069
# 4                              88   84.336362
# 5                               1  107.737471
# 6              7 25 52 67 51B 800  129.629976
# 7  F 18 49 52 51B 604 605 800 851  145.147748
# ...

# %%
# Copyright 2014 Google (map data), DigitalGlobe (imagery).
Image('qgis-bart-bus-stops.jpg')

# %% [markdown]
# ### Spatial joins

# %% [markdown]
# Relational databases are powerful because they make it easy to combine information from multiple tables (join). Spatial databases can use spatial relationships as the join key. We already used spatial joins in a limited form when comparing geometries between multiple tables.

# %%
# Which city is each BART station in?
# This is actually a join.
query("""
    SELECT station,
           name AS city
    FROM bart_stations AS bart,
         alameda_cities AS cities
    WHERE ST_Within(bart.geom, cities.geom)
    ORDER BY city
    LIMIT 5;
""")
# Out:
#              station            city
# 0      CASTRO VALLEY  Alameda County
# 1     NORTH BERKELEY        Berkeley
# 2  DOWNTOWN BERKELEY        Berkeley
# 3              ASHBY        Berkeley
# 4  DUBLIN/PLEASANTON          Dublin

# %%
# Which city is each BART station in?
# Explicit (inner) join syntax.
query("""
    SELECT station,
           name AS city
    FROM bart_stations AS bart
    JOIN alameda_cities AS cities
    ON ST_Within(bart.geom, cities.geom)
    ORDER BY city
    LIMIT 5;
""")
# Out:
#              station            city
# 0      CASTRO VALLEY  Alameda County
# 1     NORTH BERKELEY        Berkeley
# 2  DOWNTOWN BERKELEY        Berkeley
# 3              ASHBY        Berkeley
# 4  DUBLIN/PLEASANTON          Dublin

# %%
# Query baseline racial make-up of Alameda County.
query("""
    SELECT 100. * sum(pop_white) / sum(pop_total) AS pct_white,
           100. * sum(pop_black) / sum(pop_total) AS pct_black,
           100. * sum(pop_asian) / sum(pop_total) AS pct_asian,
           sum(pop_total) AS pop_total
    FROM alameda_blocks AS blocks
""")
# Out:
#    pct_white  pct_black  pct_asian  pop_total
# 0  42.980498  12.610386  26.125113    1510271

# %%
# Query racial make-up of five "diverse" cities in Alameda County.
query("""
    SELECT name,
           100. * sum(pop_white)  / sum(pop_total) AS pct_white,
           100. * sum(pop_black)  / sum(pop_total) AS pct_black,
           100. * sum(pop_native) / sum(pop_total) AS pct_native,
           100. * sum(pop_asian)  / sum(pop_total) AS pct_asian,
           100. * sum(pop_other)  / sum(pop_total) AS pct_other,
           sum(pop_total) AS pop_total
    FROM alameda_blocks AS blocks
    JOIN alameda_cities AS cities
    ON ST_Within(blocks.geom, cities.geom)
    WHERE name <> 'Alameda County'
    GROUP BY name
    ORDER BY pct_white
    LIMIT 5
""")
# Out:
#           name  pct_white  pct_black  pct_native  pct_asian  pct_other  \
# 0   Union City  23.640444   6.420193    0.491780  50.849076  18.598507
# 1      Fremont  32.863502   3.323404    0.460428  50.535732  12.816933
# 2      Hayward  33.294708  11.523615    0.960866  22.410667  31.810144
# 3      Oakland  33.917973  28.181635    0.790963  17.079755  20.029674
# 4  San Leandro  38.479489  12.072022    0.805907  29.138879  19.503704
#
#    pop_total
# 0      62833
# 1     209153
# 2     132901
# 3     376756
# 4      78421

# %%
# Query racial make-up within 200 meters of ten BART stations in Alameda.
query("""
    SELECT station,
           100. * sum(pop_white) / sum(pop_total) AS pct_white,
           100. * sum(pop_black) / sum(pop_total) AS pct_black,
           100. * sum(pop_asian) / sum(pop_total) AS pct_asian,
           sum(pop_total) AS pop_total
    FROM alameda_blocks AS blocks
    JOIN bart_stations  AS stations
    ON ST_DWithin(blocks.geom, stations.geom, 200)
    WHERE pop_total > 0
    GROUP BY station
    ORDER BY pct_white
    LIMIT 10;
""")
# Out:
#                           station  pct_white  pct_black  pct_asian  pop_total
# 0     12TH ST/OAKLAND CITY CENTER   5.048860   3.094463  90.390879        614
# 1                    LAKE MERRITT   6.176305   3.874228  88.265020       1781
# 2                         FREMONT  13.953488   1.993355  71.926910       1204
# 3                    WEST OAKLAND  14.887640  39.794007  24.438202       1068
# 4                      UNION CITY  17.667984   7.905138  60.118577       2530
# 5  COLISEUM/OAKLAND AIRPORT (OAK)  18.666667  37.333333   1.333333         75
# 6                         HAYWARD  27.827381  27.306548  23.735119       1344
# 7                       FRUITVALE  27.833753   9.949622   7.556675        794
# 8                     SAN LEANDRO  29.961588  17.669654  33.290653        781
# 9             19TH STREET/OAKLAND  30.062305  36.137072  23.208723        642

# %% [markdown]
# ### Geometry Constructing Functions

# %% [markdown]
# "Geometry constructing functions" take geometries as inputs and output new shapes. Here are some examples:
#
#  - [`ST_Centroid`](http://postgis.net/docs/ST_Centroid.html): point near center of mass
#  - [`ST_Buffer`](http://postgis.net/docs/ST_Buffer.html): extend boundary outward by buffer distance
#  - [`ST_Intersection`](http://postgis.net/docs/ST_Intersection.html): geometry region in common
#  - [`ST_Union`](http://postgis.net/docs/ST_Union.html): merged geometry
#  - [`ST_Collect`](http://postgis.net/docs/ST_Collect.html): aggregates geometries like `ST_Union`, but much faster because it doesn't dissolve intersecting regions

# %%
# From Introduction to PostGIS by Boundless
Image('http://workshops.boundlessgeo.com/postgis-intro/_images/centroid.jpg')

# %%
# Query racial make-up within 100 meters of BART routes in Alameda.
# Use ST_Centroid to speed up calculations.
query("""
    SELECT route,
           100. * sum(pop_white) / sum(pop_total) AS pct_white,
           100. * sum(pop_black) / sum(pop_total) AS pct_black,
           100. * sum(pop_asian) / sum(pop_total) AS pct_asian,
           sum(pop_total) AS pop_total
    FROM alameda_blocks AS blocks
    JOIN bart_routes    AS routes
    ON ST_DWithin(ST_Centroid(blocks.geom), routes.geom, 100)
    GROUP BY route
    ORDER BY pct_white
    LIMIT 10;
""")
# Out:
#                                     route  pct_white  pct_black  pct_asian  \
# 0          Dublin/Pleasanton to Daly City  23.145331  18.406272  37.795460
# 1                    Fremont to Daly City  26.006463  14.164430  33.652845
# 2  Pittsburg/Bay Point to SFO to Millbrae  33.360210  27.292884  26.990526
# 3                     Fremont to Richmond  33.925835  15.319491  28.984064
# 4       Richmond to Daly City to Millbrae  42.809581  19.633774  25.228891
#
#    pop_total
# 0       8546
# 1      18257
# 2       4961
# 3      26104
# 4      10813

# %%
# From Introduction to PostGIS by Boundless
Image('http://workshops.boundlessgeo.com/postgis-intro/_images/st_buffer.png')

# %%
# From Introduction to PostGIS by Boundless
Image('http://workshops.boundlessgeo.com/postgis-intro/_images/intersection.jpg')

# %%
# From Introduction to PostGIS by Boundless
Image('http://workshops.boundlessgeo.com/postgis-intro/_images/union.jpg')

# %% [markdown]
# ### Exercises

# %% [markdown]
# 1. Which BART lines service Downtown Berkeley?
# 2. Which cities are served by the 800 AC Transit bus?
# 3. Which Alameda County city has the lowest population density?
# 4. Import the Craigslist rent data into PostgreSQL. Are rents higher near BART stations and/or AC Transit bus stops?

# %% [markdown]
# ## Appendix
#
# Data sources:
#
#  - [Census - 2010 TIGER shapefiles](http://www.census.gov/cgi-bin/geo/shapefiles2010/main): [blocks in Alameda County](http://www2.census.gov/geo/tiger/TIGER2010/TABBLOCK/2010/tl_2010_06001_tabblock10.zip)
#  - [Census - American FactFinder](http://factfinder2.census.gov): 2010 Census Summary File 1 - Table P3 (Race) - for all blocks in Alameda County
#  - [Alameda Geospatial Data Files](http://acgov.org/government/geospatial.htm): [city limits](http://acgov.org/maps/geospatial/City_Limits.zip)
#  - [AC Transit Data Resource Center](http://www.actransit.org/planning-focus/data-resource-center/): [bus routes](http://www.actransit.org/wp-content/uploads/Fall14RouteShape.zip) and [bus stops](http://www.actransit.org/wp-content/uploads/Fall14stops.zip)
#  - [Caltrans GIS Data Library](http://www.dot.ca.gov/hq/tsip/gis/datalibrary/) - [BART Routes and Stations](http://www.dot.ca.gov/hq/tsip/gis/datalibrary/Metadata/BART_13.html): ["bus" routes](http://www.dot.ca.gov/hq/tsip/gis/datalibrary/zip/rail/BART_13.zip) and ["bus" stations](http://www.dot.ca.gov/hq/tsip/gis/datalibrary/zip/rail/BART_Sta_13.zip)
#  - [Berkeley Data Download Catalog](http://www.cityofberkeley.info/ContentDisplay.aspx?id=55708): [street network](http://www.cityofberkeley.info/uploadedFiles/IT/GIS/streets.zip) and [land area](http://www.cityofberkeley.info/uploadedFiles/IT/GIS/COB_LAND.zip)
#  - [MTC GIS Data](http://www.mtc.ca.gov/maps_and_data/GIS/data.htm): [bay area transit shapefiles](http://www.mtc.ca.gov/maps_and_data/GIS/gisdata/Transit_DB_Shapefiles.zip)
#
# Data was loaded from shapefiles and CSV files. Shapefiles were imported into the database using `shp2pgsql`. The projection SRID was found by using [prj2EPSG](http://prj2epsg.org/). Geometries were validated using `ST_IsValid` function and reprojected to NAD83(HARN) / California zone 3 (SRID 2768). Attribute and geometry tables were joined into a new table. Columns were renamed or deleted for convenience.
#
# This tutorial was inspired by [Introduction to PostGIS](http://workshops.boundlessgeo.com/postgis-intro/) and is licensed under the [Creative Commons Attribution-Share Alike, United States License](http://creativecommons.org/licenses/by-sa/3.0/us/).
